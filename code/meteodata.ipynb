# %%
import pandas as pd

# %%
df_mois = pd.read_csv(f'../meteodata/Illhorn1_2019-2021.csv')
df_mois
# Out:
#                       Illhorn1    SM10cm   SM30cm    SM50cm    SM80cm  T10cm  \
# 0      2019-10-16 13:00:00.000  0.046208  0.00865 -0.073909  0.043666    1.5
# 1      2019-10-16 14:00:00.000  0.118347  0.16234  0.024815  0.076898    1.3
# 2      2019-10-16 15:00:00.000  0.117448  0.16343  0.027667  0.076898    1.2
# 3      2019-10-16 16:00:00.000  0.116097  0.16234  0.030495  0.077380    1.2
# 4      2019-10-16 17:00:00.000  0.115195  0.16234  0.031433  0.077380    1.2
# ...                        ...       ...      ...       ...       ...    ...
# 17274  2021-10-05 07:00:43.315  0.114743  0.11983  0.038841  0.111571    4.9
# 17275  2021-10-05 08:00:43.320  0.116548  0.11983  0.038841  0.111571    4.8
# 17276  2021-10-05 09:00:43.325  0.117898  0.12092  0.038841  0.111116    4.8
# 17277  2021-10-05 10:00:43.330  0.119692  0.12201  0.038841  0.112025    4.8
# 17278  2021-10-05 11:00:43.335  0.121926  0.12419  0.038841  0.111571    4.9
#
#        T30cm  T80cm
# 0        2.1    2.9
# ...
